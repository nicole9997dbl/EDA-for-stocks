# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
### importing tickers###

# %%
AABA = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/AABA_2006-01-01_to_2018-01-01.csv')
AAPL = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/AAPL_2006-01-01_to_2018-01-01.csv')
AMZN = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/AMZN_2006-01-01_to_2018-01-01.csv')
AXP = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/AXP_2006-01-01_to_2018-01-01.csv')
BA = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/BA_2006-01-01_to_2018-01-01.csv')
CAT = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/CAT_2006-01-01_to_2018-01-01.csv')
CSCO = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/CSCO_2006-01-01_to_2018-01-01.csv')
CVX = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/CVX_2006-01-01_to_2018-01-01.csv')
DIS = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/DIS_2006-01-01_to_2018-01-01.csv')
GE = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/GE_2006-01-01_to_2018-01-01.csv')
GOOGL = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/GOOGL_2006-01-01_to_2018-01-01.csv')
GS = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/GS_2006-01-01_to_2018-01-01.csv')
HD = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/HD_2006-01-01_to_2018-01-01.csv')
IBM = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/IBM_2006-01-01_to_2018-01-01.csv')
INTC = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/INTC_2006-01-01_to_2018-01-01.csv')
JNJ = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/JNJ_2006-01-01_to_2018-01-01.csv')
JPM = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/JPM_2006-01-01_to_2018-01-01.csv')
KO = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/KO_2006-01-01_to_2018-01-01.csv')
MCD = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/MCD_2006-01-01_to_2018-01-01.csv')
MMM = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/MMM_2006-01-01_to_2018-01-01.csv')
MRK = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/MRK_2006-01-01_to_2018-01-01.csv')
MSFT = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/MSFT_2006-01-01_to_2018-01-01.csv')
NKE = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/NKE_2006-01-01_to_2018-01-01.csv')
PFE = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/PFE_2006-01-01_to_2018-01-01.csv')
PG = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/PG_2006-01-01_to_2018-01-01.csv')
TRV = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/TRV_2006-01-01_to_2018-01-01.csv')
UNH = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/UNH_2006-01-01_to_2018-01-01.csv')
UTX = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/UTX_2006-01-01_to_2018-01-01.csv')
VZ = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/VZ_2006-01-01_to_2018-01-01.csv')
WMT = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/WMT_2006-01-01_to_2018-01-01.csv')
XOM = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/XOM_2006-01-01_to_2018-01-01.csv')
stocks_lastyear  = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/all_stocks_2017-01-01_to_2018-01-01.csv')
allstocks = pd.read_csv('C:/Users/nicol/Documents/6340#Python/Midterm Project/stock-time-series-20050101-to-20171231 (1)/all_stocks_2006-01-01_to_2018-01-01.csv')

# %%
###### Adding some descriptive values into the all_staock tables######

allstocks['OHLC'] = (allstocks.Open + allstocks.Close + allstocks.High + allstocks.Low)*1.0/4

# %%
######### Overall stock price for the past 12 years ####################
by_day = allstocks.groupby('Date').mean().reset_index()
by_day.Date = pd.to_datetime(by_day.Date)
by_day.plot(x='Date',y='Close')
by_day.plot(x='Date',y='Open')
by_day.plot(x='Date',y='High')
by_day.plot(x='Date',y='Low')
plt.show()

# %%
### We can see a very steep jump in Open price and Low price close to the year 2018. Let's figure out what is that period.###
stocks_lastyear.Date = pd.to_datetime(stocks_lastyear.Date)
by_day_lastyear = stocks_lastyear.groupby('Date').mean().reset_index()
by_day_lastyear.plot(x='Date',y='Open')
plt.show()

# %%
### So the big jump of overall avrage stock price happened between July and August 2017. Let's find out. ###
by_day_lastyear.sort_values('Open',ascending=False).head(10)
# Out:
#           Date        Open        High         Low       Close        Volume
# 144 2017-07-31  332.708571  182.239091  226.246667  161.499355  1.016487e+07
# 244 2017-12-20  186.067419  186.447742  184.163548  184.833548  1.137514e+07
# 243 2017-12-19  186.039355  186.619032  184.352258  185.452903  1.112914e+07
# 242 2017-12-18  185.419355  186.875484  184.519032  185.856129  1.136914e+07
# 249 2017-12-28  185.240000  185.665806  184.297419  184.943871  6.558984e+06
# 245 2017-12-21  185.092258  186.148065  183.832581  184.915484  1.100908e+07
# 250 2017-12-29  184.924194  185.338387  183.587742  183.791935  8.775666e+06
# 248 2017-12-27  184.845806  185.518387  183.946774  184.681613  7.374016e+06
# 246 2017-12-22  184.816452  185.373871  183.792903  184.488065  8.743227e+06
# 247 2017-12-26  184.319355  185.290645  183.348387  184.581613  6.884408e+06

# %%
stocks_lastyear[stocks_lastyear.Date=='2017-07-31']
# Out:
#            Date     Open     High     Low   Close    Volume   Name
# 144  2017-07-31      NaN   201.66     NaN  201.17   1833625    MMM
# 395  2017-07-31      NaN    85.70     NaN   85.23   3079797    AXP
# 646  2017-07-31   149.90   150.33  148.13  148.73  19845920   AAPL
# 897  2017-07-31      NaN      NaN     NaN  242.46   5777271     BA
# 1148 2017-07-31      NaN      NaN     NaN  113.95   4486013    CAT
# 1399 2017-07-31      NaN   110.00     NaN  109.19   7561205    CVX
# 1650 2017-07-31    31.54    31.59   31.37   31.45  19256428   CSCO
# 1901 2017-07-31      NaN      NaN   45.79   45.84  13622891     KO
# 2152 2017-07-31      NaN   110.14     NaN  109.93   6815349    DIS
# 2403 2017-07-31      NaN    80.39     NaN   80.04  12820175    XOM
# 2654 2017-07-31      NaN    25.69     NaN   25.61  30616287     GE
# 2905 2017-07-31      NaN   225.50     NaN  225.33   1999637     GS
# 3156 2017-07-31      NaN   149.98     NaN  149.60   5253318     HD
# ...

# %%
### we can see that a lot of the information are missing on the day of July31,2017 in the all stock files. So the abnormal jump
### in the price probably not reliable. We ignore that. Let's look at the overall prices again.
allstocks=allstocks[allstocks.Date != "2017-07-31"]
by_day = allstocks.groupby('Date').mean().reset_index()
by_day.Date = pd.to_datetime(by_day.Date)
plt.plot(by_day.Date,by_day.Open)
plt.plot(by_day.Date,by_day.Close)
plt.show()
### Report:the average stock price over the past 12 years were climbing up generally, but there is a fall down between the year
### of 2008 and the year of 2010.

# %%
### The top 10 most expensive stocks last year ###
stocks_lastyear['OHLC'] = (stocks_lastyear.Open + stocks_lastyear.High + stocks_lastyear.Low + stocks_lastyear.Close)*1.0/4
by_name_lastyear = stocks_lastyear.groupby('Name').mean().reset_index()
by_name_lastyear.sort_values('OHLC',ascending=False).head(10).reset_index(drop=True)[['Name','OHLC']]
# Out:
#     Name        OHLC
# 0   AMZN  967.923835
# 1  GOOGL  939.415120
# 2     GS  233.716190
# 3     BA  215.027530
# 4    MMM  205.226040
# 5    UNH  186.059680
# 6    IBM  157.748760
# 7     HD  155.313020
# 8   AAPL  150.472311
# 9    MCD  148.684710

# %%
### I am interested in Apple, so I am conducting an EDA on Apple's stock.###
AAPL['OHLC'] = (AAPL.Open + AAPL.High + AAPL.Low + AAPL.Close)*1.0/4
AAPL['Fluctuation']=AAPL['High']-AAPL['Low']
AAPL['Performance']=AAPL['Close']-AAPL['Open']
AAPL['MA10DAY'] = AAPL.Close.rolling(window=10).mean()
AAPL['MA50DAY'] = AAPL.Close.rolling(window=50).mean()
AAPL['Date'] = pd.to_datetime(AAPL['Date'])
### Visualization of Apple stock in terms of the OHLC and the moving averages ###
fig, ax = plt.subplots(figsize=(10, 8))
AAPL.plot('Date','OHLC',ax=ax)
AAPL.plot('Date','MA50DAY',ax=ax)

# %%
### Let's look at Apple's stock last year ###
### I am interested in Apple, so I am conducting an EDA on Apple's stock.###
AAPL2017 = stocks_lastyear[stocks_lastyear.Name=='AAPL']
AAPL2017['MA50DAY'] = AAPL2017.Close.rolling(window=50).mean()
AAPL2017['Date'] = pd.to_datetime(AAPL2017['Date'])
### Visualization of Apple stock in terms of the OHLC and the moving averages ###
fig, ax = plt.subplots(figsize=(10, 8))
AAPL2017.plot('Date','OHLC',ax=ax)
AAPL2017.plot('Date','MA50DAY',ax=ax)
# Out:
# C:\Users\nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\nicol\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
### A deeper investigation of Apple's stock price in Dec 2017 ###
### Are there any relationships between the volume and price change?###

fig, ax1 = plt.subplots(figsize=(12, 6))
x=np.array(AAPL2017Dec.Date)

y=np.array(AAPL2017Dec.OHLC)
size = np.array(AAPL2017Dec.Volume)

ax1.plot(x, AAPL2017Dec.MA10DAY,c = 'r', label = 'MA10DAY')
ax1.plot(x,y, 'o', c = 'b', label = "OHLC")
plt.xticks(rotation = 90)
ax1.tick_params(axis = 'both', which = 'both', direction = 'in')
ax1.tick_params(axis = 'y', labelcolor = 'r', labelsize = 15 )
ax1.set_xlabel('Date', fontsize = 15)
ax1.set_ylabel('Price (USD)', fontsize = 15)
ax1.legend(loc = 1)


ax2 = ax1.twinx()
ax2.bar(x, size, color = 'g', alpha = 0.5, label = 'Volume (USD)')
ax2.set_ylabel('Volume', fontsize = 15)
ax2.tick_params(axis = 'y', labelcolor = 'g', direction = 'in', \
                 labelsize = 15)

ax2.legend(loc = 2)
plt.tight_layout()
plt.savefig('abcd.png', dpi = 300)

# %%
### What are the top 5 volume days? ###
AAPL.sort_values('Volume',ascending=False).head(5).reset_index(drop=True)
# Out:
#         Date   Open   High    Low  Close     Volume  Name     OHLC  \
# 0 2008-01-23  19.46  20.00  18.02  19.87  843264044  AAPL  19.3375
# 1 2007-01-09  12.35  13.28  12.16  13.22  838036682  AAPL  12.7525
# 2 2007-01-10  13.54  13.97  13.35  13.86  739605951  AAPL  13.6800
# 3 2006-04-06   9.76  10.29   9.74  10.18  666021972  AAPL   9.9925
# 4 2008-09-29  17.09  17.10  14.37  15.04  655513663  AAPL  15.9000
#
#    Fluctuation  Performance  MA10DAY  MA50DAY
# 0         1.98         0.41   23.633  25.5312
# 1         1.12         0.87   12.049  12.2226
# 2         0.62         0.32   12.261  12.2650
# 3         0.55         0.42    8.975   9.5730
# 4         2.73        -2.05   18.497  22.5464

# %%
### Q2 Report: The Apple stock price has been growing in general for the past 12 years. It experienced two big falls during the
###            past 12 years. One is in 2013 and the other is in 2016. During the period, the maxium volume appeared on 
###            2018-01-23, when it had a volume of 843264044. The stock volume and stock price are not neccessary related
###            here based my analysis for Dec, 2017.

# %%
### Comparison between APPLE and AMAZON in terms of daily average price and volume ###
AMZN['OHLC'] = (AMZN.Open + AMZN.High + AMZN.Low + AMZN.Close)*1.0/4
AAPL['Date'] = pd.to_datetime(AAPL['Date'])
AMZN['Date'] = pd.to_datetime(AMZN['Date'])
fig, ax = plt.subplots(2,figsize=(10, 8))
ax[0].plot(AMZN.Date, AMZN.OHLC,c='blue', label='Amazon OHLC Price')
ax[0].plot(AAPL.Date, AAPL.OHLC,c='orange', label='Apple OHLC Price')
ax[0].legend()
ax[1].plot(AMZN.Date, AMZN.Volume, c='blue', label='Amazon Volume')
ax[1].plot(AAPL.Date, AAPL.Volume, c='orange',label='Apple Volume')
ax[1].legend()

# %%
# Q3 Report: In general, Amazon's stock price is higher than Apple's. Both Amazon and Apple's stocks price are growing during
###            the past 12 years. However, Amazon's stock is growing faster than Apples', especially after 2015,
###            when Amazon's stock price started to grow rapidly. Apple's stock price, on the other hand, has always
###            been growing gently and slowly during the past 12 years. Before the year of 2008, the differece of stock price
###            is small. However, Amazon's stock price is 6 times as Apple's stock price at the end of the year 2017.

###            In terms of volumes, Apple's daily stock volume is higher than Amazon's in general while it's gradually 
###            decreasing over the years. And Apple has a much more fluctuating stock volume than Amazon, but the fluctuation is 
###            decreasing over the years. The daily stock volume of Amazon maintains stable except for some minor fluctuations.

# %%
### Analysis for Amazon, Google, IBM, Microsoft and Apple.###

fig, ax = plt.subplots(2,figsize=(20, 20))
GOOGL['OHLC'] = (GOOGL.Open + GOOGL.High + GOOGL.Low + GOOGL.Close)*1.0/4
GOOGL['Date'] = pd.to_datetime(GOOGL['Date'])
IBM['OHLC'] = (IBM.Open + IBM.High + IBM.Low + IBM.Close)*1.0/4
IBM['Date'] = pd.to_datetime(IBM['Date'])
MSFT['OHLC'] = (MSFT.Open + MSFT.High + MSFT.Low + MSFT.Close)*1.0/4
MSFT['Date'] = pd.to_datetime(MSFT['Date'])
ax[0].plot(MSFT.Date, MSFT.OHLC, label='Microsoft OHLC Price')
ax[0].plot(IBM.Date, IBM.OHLC, label='IBM OHLC Price')
ax[0].plot(GOOGL.Date, GOOGL.OHLC, label='Google OHLC Price')
ax[0].plot(AMZN.Date, AMZN.OHLC, label='Amazon OHLC Price')
ax[0].plot(AAPL.Date, AAPL.OHLC, label='Apple OHLC Price')
ax[0].legend()
ax[1].plot(AMZN.Date, AMZN.Volume, label='Amazon Volume')
ax[1].plot(AAPL.Date, AAPL.Volume, label='Apple Volume')
ax[1].plot(GOOGL.Date, GOOGL.Volume, label='Google Volume')
ax[1].plot(IBM.Date, IBM.Volume, label='IBM Volume')
ax[1].plot(MSFT.Date, MSFT.Volume, label='Microsoft Volume')
ax[1].legend()

# %%
AAPL['Volume'].mean()
# Out:
# 131145687.66379596

# %%
MSFT['Volume'].mean()
# Out:
# 51617615.46107983

# %%
### Q4 Report: Analysis for Amazon, Google, IBM, Microsoft and Apple.###
# In terms of stock price: 
#     All of the five stocks price were generally increasing, except for IBM, who showed a decreasing 
# tendency after reaching its peak in 2013. Amazon stock price experienced the most rapid growth(multipled twelvefold) during 
# the past 12 years, making it to the fisrt place from the third place among the five stocks. Google had the highest stock 
# price until 2016, when it was catched up by Amazon. Amazon and Google are the only companys whose stock price reached $1000
# in history. The other 3 stocks were below $200.(IBM reached $200 for a short time during its peak in 2013)
#     Amazon and Google also have the most fluctuating stock price among the five stocks. Interestingly, they showed a very 
# similar fluctuation pattern. The other three stock price are relatively stable. Microsoft has the most stable stock price
# over the past 12 years.

# In terms of stock volume:
#     Generally speaking, Apple had the highest daily stock volumes over the past 12 years with an average of 131145688, 
# followed by Microsoft with an average of 51617615. At the same time, these two stocks also have the most fluctuating volume. 
# The fluctuation of daily stock volume between Apple and Microsoft are very similar. But overall speaking, the stock volume
# fluctuation range has been decreasing over the years.
